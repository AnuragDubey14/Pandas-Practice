# %% [markdown]
# # importing required library

# %%
import pandas as pd
import numpy as np

# %%
#read the data
df=pd.read_csv(r"C:\Users\Lenovo\Documents\jupyter\DataSets\automobile_data.csv")

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.sample(10)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 170          2               134      toyota       gas        std
# 97           1               103      nissan       gas        std
# 83           3                 ?  mitsubishi       gas      turbo
# 39           0                85       honda       gas        std
# 63           0                 ?       mazda    diesel        std
# 147          0                89      subaru       gas        std
# 180         -1                90      toyota       gas        std
# 37           0               106       honda       gas        std
# 82           3                 ?  mitsubishi       gas      turbo
# 13           0               188         bmw       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 170          two    hardtop          rwd           front        98.4  ...
# 97          four      wagon          fwd           front        94.5  ...
# ...

# %% [markdown]
# ## question 1- Convert all the ‘?’ values to NaN. Clean the data as per further requirements.

# %%
df.replace('?',np.nan,inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# ## Question 2- Which company manufactured the most expensive car and at what price?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df[['price']].sample(20)
# Out:
#      price
# 69   28176
# 156   6938
# 95    7799
# 52    6795
# 21    5572
# 111  15580
# 137  18620
# 164   8238
# 34    7129
# 94    7299
# 165   9298
# 153   6918
# 26    7609
# 185   8195
# 136  18150
# 87    9279
# 121   6692
# 135  15510
# 40   10295
# 109  12440

# %%
df.price.isnull().sum()
# Out:
# 4

# %%
df.price.replace(np.nan,0,inplace=True)

# %%
df['price']=df['price'].astype(int)

# %%
new_df=df.sort_values(by=['price'],ascending=False)
new_df.head(1)
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 74          1               NaN  mercedes-benz       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 74          two    hardtop          rwd           front       112.0  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 74          304         mpfi   3.8    3.35               8.0        184
#
#     peak-rpm city-mpg highway-mpg  price
# 74      4500       14          16  45400
#
# [1 rows x 26 columns]

# %% [markdown]
# ## Question 3- Calculate the maximum horsepower for each company.

# %%
df.groupby('make').horsepower.max()
# Out:
# make
# alfa-romero      154
# audi             160
# bmw              182
# chevrolet         70
# dodge             88
# honda             86
# isuzu             90
# jaguar           262
# mazda             84
# mercedes-benz    184
# mercury          175
# mitsubishi        88
# nissan            97
# peugot            97
# plymouth          88
# porsche          288
# renault          NaN
# saab             160
# subaru            94
# toyota            92
# volkswagen        90
# volvo            162
# Name: horsepower, dtype: object

# %% [markdown]
# ## Question 4- What is the total count of cars manufactured by each company?

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# ## question 5- Based on new regulations, companies decided to change the prices of the car. The new update price is calculated as - if the engine is in front, the price will be the same else if the engine is in the rear, the price will be doubled. Add a new column with the updated prices.

# %%
df['engine-location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
def value_data(price,engine):
    if engine=='front':
        return price
    elif engine=='rear':
        return price*2

# %%
df['price_update']=df.apply(lambda x: value_data(x['price'],x['engine-location']),axis=1)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 0  convertible          rwd           front        88.6  ...         mpfi
# 1  convertible          rwd           front        88.6  ...         mpfi
# 2    hatchback          rwd           front        94.5  ...         mpfi
# 3        sedan          fwd           front        99.8  ...         mpfi
# 4        sedan          4wd           front        99.4  ...         mpfi
#
# ...

# %% [markdown]
# ## question 6- Sort the data frame according to car and price combined.

# %%
df.sort_values(by=['price','make'])
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 9            0               NaN           audi       gas      turbo
# 44           1               NaN          isuzu       gas        std
# 45           0               NaN          isuzu       gas        std
# 129          1               NaN        porsche       gas        std
# 138          2                83         subaru       gas        std
# ..         ...               ...            ...       ...        ...
# 17           0               NaN            bmw       gas        std
# 128          3               NaN        porsche       gas        std
# 73           0               NaN  mercedes-benz       gas        std
# 16           0               NaN            bmw       gas        std
# 74           1               NaN  mercedes-benz       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# ## question 7- Create a new column which stores the number of doors in a car as integers.

# %%
df['num-of-doors'].unique()
# Out:
# array(['two', 'four', nan], dtype=object)

# %%
def value(doors):
    if doors =='two':
        return 2
    elif doors=='four':
        return 4
    else:
        return np.nan

# %%
df['number_of_doors_numeric']= df['num-of-doors'].apply(value)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# ## question 9-Concatenate the two data frames given below firstly row-wise and secondly column wise.

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845,
171995, 135925, 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995,
23600, 61500, 58900]}

# %%
df_german=pd.DataFrame(GermanCars)
df_japanese=pd.DataFrame(japaneseCars)

# %%
df_german
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
df_japanese
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
# row wise concatenation

new_df1=pd.concat([df_german,df_japanese],axis=0)
new_df1
# Out:
#        Company   Price
# 0         Ford   23845
# 1     Mercedes  171995
# 2          BMV  135925
# 3         Audi   71400
# 0       Toyota   29995
# 1        Honda   23600
# 2       Nissan   61500
# 3  Mitsubishi    58900

# %%
# column wise concatenation
new_df2=pd.concat([df_german,df_japanese],axis=1)
new_df2
# Out:
#     Company   Price      Company  Price
# 0      Ford   23845       Toyota  29995
# 1  Mercedes  171995        Honda  23600
# 2       BMV  135925       Nissan  61500
# 3      Audi   71400  Mitsubishi   58900

# %% [markdown]
# ## Save the first and last records of the dataframe in a separate Excel sheet.

# %%
df1=df.copy()
df.tail(15).to_excel('automobile_new.xlsx', sheet_name='End15')

# %%
df1.head(15).to_excel('automobile_new.xlsx', sheet_name='Start15' )
