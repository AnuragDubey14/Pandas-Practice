# %% [markdown]
# # Business Case Questions
# - Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.
# - Q. 2) Remove all the records where the Confirmed Cases is Less Than 10.
# - Q. 3) In which Region, maximum number of Confirmed cases were recorded ?
# - Q. 4) In which Region, minimum number of Deaths cases were recorded ?
# - Q. 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?
# - Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.
# - Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
#Importing Required Library
import pandas as pd
import numpy as np

# %%
#read the data
df=pd.read_csv(r"C:\Users\Lenovo\Documents\jupyter\DataSets\4. covid_19_data.csv")

# %%
df.sample(10)
# Out:
#           Date                     State          Region  Confirmed  Deaths  \
# 237  4/29/2020                   Jiangsu  Mainland China        653       0
# 232  4/29/2020                  Illinois              US      50358    2215
# 306  4/29/2020  Turks and Caicos Islands              UK         12       1
# 3    4/29/2020                       NaN         Andorra        743      42
# 127  4/29/2020                       NaN        Paraguay        239       9
# 255  4/29/2020                   Montana              US        451      16
# 129  4/29/2020                       NaN     Philippines       8212     558
# 85   4/29/2020                       NaN      Kazakhstan       3138      25
# 293  4/29/2020                  Shanghai  Mainland China        647       7
# 33   4/29/2020                       NaN           Chile      14885     216
#
#      Recovered
# 237        648
# 232          0
# 306          5
# 3          423
# 127        102
# 255          0
# 129       1023
# ...

# %%
pd.set_option("display.max_rows",None)

# %%
df.shape
# Out:
# (321, 6)

# %%
df.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
df.size
# Out:
# 1926

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# # Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
df.groupby('Region')[['Confirmed','Deaths','Recovered']].sum().sort_values(by='Confirmed',ascending=False)
# Out:
#                                   Confirmed  Deaths  Recovered
# Region
# US                                  1039909   60967     120720
# Spain                                236899   24275     132929
# Italy                                203591   27682      71252
# France                               166543   24121      49118
# UK                                   166441   26166        857
# Germany                              161539    6467     120400
# Turkey                               117589    3081      44040
# Russia                                99399     972      10286
# Iran                                  93657    5957      73791
# Mainland China                        82862    4633      77610
# Brazil                                79685    5513      34132
# Canada                                52865    3155      20327
# Belgium                               47859    7501      11283
# Netherlands                           38998    4727        119
# ...

# %%
df['Region'].nunique()
# Out:
# 187

# %% [markdown]
# # Q. 2) Remove all the records where the Confirmed Cases is Less Than 10.

# %%
df[df['Confirmed']<10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
df=df.drop(df[df['Confirmed']<10].index)

# %%
df
# Out:
#           Date                         State  \
# 0    4/29/2020                           NaN
# 1    4/29/2020                           NaN
# 2    4/29/2020                           NaN
# 3    4/29/2020                           NaN
# 4    4/29/2020                           NaN
# 5    4/29/2020                           NaN
# 6    4/29/2020                           NaN
# 7    4/29/2020                           NaN
# 8    4/29/2020                           NaN
# 9    4/29/2020                           NaN
# 10   4/29/2020                           NaN
# 11   4/29/2020                           NaN
# 12   4/29/2020                           NaN
# 13   4/29/2020                           NaN
# 14   4/29/2020                           NaN
# 15   4/29/2020                           NaN
# 16   4/29/2020                           NaN
# 17   4/29/2020                           NaN
# 19   4/29/2020                           NaN
# 20   4/29/2020                           NaN
# ...

# %% [markdown]
# # Q. 3) In which Region, maximum number of Confirmed cases were recorded ?

# %%
df.groupby('Region')[['Confirmed']].sum().sort_values(by='Confirmed',ascending=False)
# Out:
#                                   Confirmed
# Region
# US                                  1039909
# Spain                                236899
# Italy                                203591
# France                               166536
# UK                                   166432
# Germany                              161539
# Turkey                               117589
# Russia                                99399
# Iran                                  93657
# Mainland China                        82861
# Brazil                                79685
# Canada                                52860
# Belgium                               47859
# Netherlands                           38993
# Peru                                  33931
# India                                 33062
# Switzerland                           29407
# Ecuador                               24675
# Portugal                              24505
# Saudi Arabia                          21402
# ...

# %% [markdown]
# # Q. 4) In which Region, minimum number of Deaths cases were recorded ?

# %%
df.groupby('Region')[['Deaths']].sum().sort_values(by='Deaths')
# Out:
#                                   Deaths
# Region
# Cambodia                               0
# Seychelles                             0
# Saint Lucia                            0
# Central African Republic               0
# Saint Kitts and Nevis                  0
# South Sudan                            0
# Rwanda                                 0
# Grenada                                0
# Macau                                  0
# Madagascar                             0
# Nepal                                  0
# Namibia                                0
# Saint Vincent and the Grenadines       0
# Mozambique                             0
# Holy See                               0
# Timor-Leste                            0
# Mongolia                               0
# Uganda                                 0
# Laos                                   0
# Eritrea                                0
# Vietnam                                0
# Fiji                                   0
# ...

# %% [markdown]
# # Q. 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df[(df['Region']=='India')&(df['Date']<='29-04-2020')]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11848\3108673784.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df[(df['Region']=='India')&(df['Date']<='29-04-2020')]
#          Date State Region  Confirmed  Deaths  Recovered
# 74 2020-04-29   NaN  India      33062    1079       8437

# %% [markdown]
# # Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
df.sort_values(by='Confirmed',ascending=True)
# Out:
#           Date                         State  \
# 156 2020-04-29                           NaN
# 70  2020-04-29                           NaN
# 59  2020-04-29                           NaN
# 318 2020-04-29                         Yukon
# 217 2020-04-29                     Greenland
# 256 2020-04-29                    Montserrat
# 144 2020-04-29                           NaN
# 27  2020-04-29                           NaN
# 306 2020-04-29      Turks and Caicos Islands
# 118 2020-04-29                           NaN
# 215 2020-04-29                Grand Princess
# 206 2020-04-29   Falkland Islands (Malvinas)
# 270 2020-04-29      Northern Mariana Islands
# 136 2020-04-29                           NaN
# 138 2020-04-29                           NaN
# 45  2020-04-29                           NaN
# 201 2020-04-29                       Curacao
# 114 2020-04-29                           NaN
# 137 2020-04-29                           NaN
# 260 2020-04-29                 New Caledonia
# ...

# %% [markdown]
# # Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
df.sort_values(by='Recovered',ascending=False)
# Out:
#           Date                         State  \
# 153 2020-04-29                           NaN
# 61  2020-04-29                           NaN
# 76  2020-04-29                           NaN
# 80  2020-04-29                           NaN
# 229 2020-04-29                         Hubei
# 57  2020-04-29                           NaN
# 167 2020-04-29                           NaN
# 22  2020-04-29                           NaN
# 158 2020-04-29                           NaN
# 78  2020-04-29                           NaN
# 8   2020-04-29                           NaN
# 107 2020-04-29                           NaN
# 15  2020-04-29                           NaN
# 134 2020-04-29                           NaN
# 128 2020-04-29                           NaN
# 151 2020-04-29                           NaN
# 74  2020-04-29                           NaN
# 79  2020-04-29                           NaN
# 33  2020-04-29                           NaN
# 42  2020-04-29                           NaN
# ...
